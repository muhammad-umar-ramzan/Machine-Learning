# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("spam.csv")

# %%
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df["spam"]=df["Category"].apply(lambda x: 1 if x=="ham" else 0)

# %%
x=df.Message
y=df.spam

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vector=CountVectorizer()
x_tra=vector.fit_transform(x_train)
x_tes=vector.transform(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB
naive=MultinomialNB()
naive.fit(x_tra,y_train)
# Out:
# MultinomialNB()

# %%
naive.score(x_tes,y_test)
# Out:
# 0.9811659192825112

# %%
y_predict=naive.predict(x_tes)

# %%
from sklearn.metrics import confusion_matrix
ce=confusion_matrix(y_test,y_predict)
ce
# Out:
# array([[131,  15],
#        [  6, 963]], dtype=int64)

# %%
a=['I HAVE A DATE ON SUNDAY WITH WILL!!',
'I see the letter B on my car',
  "Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged	Thanks for your subscription to Ringtone UK your mobile will be charged Â£5/month Please confirm by replying YES or NO. If you reply NO you will not be charged"]

# %%
b=vector.transform(a)
b.toarray()
naive.predict(b)
# Out:
# array([1, 1, 0], dtype=int64)

# %%
naive.predict(x_tes)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.pipeline import Pipeline

# %%
ce=Pipeline([
    ("vectoriz",CountVectorizer()),
    ("nb",MultinomialNB())
])

# %%
ce.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('vectoriz', CountVectorizer()), ('nb', MultinomialNB())])

# %%
ce.predict(x_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
ce.score(x_test,y_test)
# Out:
# 0.9811659192825112

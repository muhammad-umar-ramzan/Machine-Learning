# %%
import pandas as pd
from sklearn.datasets import load_digits

# %%
digits=load_digits()

# %%
df=pd.read_csv("heart.csv")

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df[df["Age"]>(df["Age"].mean()+3*df["Age"].std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df["RestingBP"]>(df["RestingBP"].mean()+3*df["RestingBP"].std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
df1=df[df["RestingBP"]<(df["RestingBP"].mean()+3*df["RestingBP"].std())]

# %%
df[df["Cholesterol"]>(df["Cholesterol"].mean()+3*df["Cholesterol"].std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
df2=df1[df1["Cholesterol"]<(df1["Cholesterol"].mean()+3*df1["Cholesterol"].std())]

# %%
df[df["MaxHR"]>(df["MaxHR"].mean()+3*df["MaxHR"].std())]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %%
df[df["Oldpeak"]>(df["Oldpeak"].mean()+3*df["Oldpeak"].std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# 850    145              N      6.2     Down             1
# 900    140              N      4.4     Down             1

# %%
df3=df2[df2["Oldpeak"]<(df2["Oldpeak"].mean()+3*df2["Oldpeak"].std())]

# %%
df3.shape
# Out:
# (902, 12)

# %%
df4.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   12    1              1        140          289          0           1
# 1   21    0              2        160          180          0           1
# 2    9    1              1        130          283          0           2
# 3   20    0              0        138          214          0           1
# 4   26    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df4=df3.copy()
df4["Sex"]=label.fit_transform(df4["Sex"])

# %%
df4["ChestPainType"]=label.fit_transform(df4["ChestPainType"])

# %%
df4["RestingECG"]=label.fit_transform(df4["RestingECG"])

# %%
df4["ExerciseAngina"]=label.fit_transform(df4["ExerciseAngina"])

# %%
df4["ST_Slope"]=label.fit_transform(df4["ST_Slope"])

# %%
x=df4.drop(["HeartDisease"],axis=1)
y=df4["HeartDisease"]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_scale=scaler.fit_transform(x)

# %%
x_scale[1,0:]
# Out:
# array([-0.47545956, -1.94228905,  1.27107517,  1.5925728 , -0.16132855,
#        -0.55087949,  0.01233655,  0.75291107, -0.82065181,  0.14079864,
#        -0.62072967])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scale,y,test_size=0.2,random_state=30)

# %%
from sklearn.ensemble import BaggingClassifier
bagging=BaggingClassifier( estimator=DecisionTreeClassifier(),
    n_estimators=100,
                          max_samples=0.8,
                          oob_score=True,
                          random_state=0,
)
bagging.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), max_samples=0.8,
#                   n_estimators=100, oob_score=True, random_state=0)

# %%
bagging.oob_score_
# Out:
# 0.8432732316227461

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
model=cross_val_score(DecisionTreeClassifier(),x_scale,y,cv=5)

# %%
model.mean()
# Out:
# 0.7427255985267035

# %%
model
# Out:
# array([0.80110497, 0.74585635, 0.79444444, 0.75      , 0.62222222])

# %%
from sklearn.svm import SVC
svc=cross_val_score(SVC(),x_scale,y,cv=5)
svc.mean()
# Out:
# 0.8258809085328422

# %%
svc_bagging=BaggingClassifier(estimator=SVC(),
                             n_estimators=100,
                             max_samples=0.8,
                             oob_score=True,
                             random_state=0)
svc_bagging.fit(x_scale,y)
# Out:
# BaggingClassifier(estimator=SVC(), max_samples=0.8, n_estimators=100,
#                   oob_score=True, random_state=0)

# %%
svc_bagging.oob_score_
# Out:
# 0.8736141906873615

# %%
from sklearn.ensemble import RandomForestClassifier
ran=RandomForestClassifier(n_estimators=50)
ra
